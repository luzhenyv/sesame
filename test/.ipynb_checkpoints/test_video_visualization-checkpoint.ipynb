# %% [markdown]
# # Test video Visualization

# %% [markdown]
# ## 1. Setup

# %%
import sys
# sys.path.append('/Users/zhenyvlu/work/sesame')
sys.path.append(r'C:\Users\luzhe\deep_learning\sesame')

import numpy
import torch

# %matplotlib inline
import matplotlib.pyplot as plt

import sesame.utils.logger as logger
from sesame.visualization.ava_vis import AVAVisualizerWithPrecomputedBox
from sesame.config.defaults import get_cfg

log = logger.get_logger('notebook')
logger.setup_logging('.')
# Out:
# [01/25 13:01:34][DEBUG] pyplot.py: 224: Loaded backend module://matplotlib_inline.backend_inline version unknown.

# %%
cfg = get_cfg()
cfg.merge_from_file("../configs/AVA/MVIT_B_16x4_CONV.yaml")

# %%
ava_vis = AVAVisualizerWithPrecomputedBox(cfg)
# Out:
# preds boxes path is
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10284/4079684957.py in <module>
# ----> 1 ava_vis = AVAVisualizerWithPrecomputedBox(cfg)
#
# ~\deep_learning\sesame\sesame\visualization\ava_vis.py in __init__(self, cfg)
#      55             self.output_file = self.get_output_file(cfg.DEMO.OUTPUT_FILE)
#      56
# ---> 57         self.pred_boxes, self.gt_boxes = load_boxes_labels(
#      58             cfg,
#      59             self.video_name,
#
# ~\deep_learning\sesame\sesame\visualization\ava_vis.py in load_boxes_labels(cfg, video_name, fps, img_width, img_height)
#     447         gt_boxes = gt_boxes[video_name]
#     448
# --> 449     preds_boxes = process_bboxes_dict(preds_boxes)
#     450     if gt_boxes is not None:
#     451         gt_boxes = process_bboxes_dict(gt_boxes)
#
# UnboundLocalError: local variable 'preds_boxes' referenced before assignment
