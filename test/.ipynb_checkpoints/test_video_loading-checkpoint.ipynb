# %% [markdown]
# # Test video loading

# %% [markdown]
# ## 1. Setup

# %%
import sys
# sys.path.append('/Users/zhenyvlu/work/sesame')
sys.path.append(r'C:\Users\luzhe\deep_learning\sesame')

import numpy
import torch

# %matplotlib inline
import matplotlib.pyplot as plt

import sesame.utils.logger as logger
from sesame.datasets.ava_dataset import Ava
from sesame.config.defaults import get_cfg

log = logger.get_logger('notebook')
logger.setup_logging('.')

# %%
cfg = get_cfg()
cfg.merge_from_file("../configs/AVA/MVIT_B_16x4_CONV.yaml")

# cfg = CN.load_cfg(open("../configs/Kinetics/MVIT_B_16x4_CONV.yaml", "r", encoding="UTF-8"))

# %%
ava_dataset_train = Ava(cfg, 'train')
# Out:
# [01/24 15:41:58][INFO] ava_dataset.py:  47: Finished loading annotations from: %s
# [01/24 15:41:58][INFO] ava_dataset.py:  48: Detection threshold: 0.9
# [01/24 15:41:58][INFO] ava_dataset.py:  49: Number of unique boxes: 1132
# [01/24 15:41:58][INFO] ava_dataset.py:  50: Number of annotations: 3009
# [01/24 15:41:58][INFO] ava_dataset.py:  98: 706 keyframes used.
# [01/24 15:41:58][INFO] ava_dataset.py: 243: === AVA dataset summary ===
# [01/24 15:41:58][INFO] ava_dataset.py: 244: Split: train
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3920/2138489847.py in <module>
# ----> 1 ava_dataset_train = Ava(cfg, 'train')
#
# ~\deep_learning\sesame\sesame\datasets\ava_dataset.py in __init__(self, cfg, split)
#     210             self._test_force_flip = cfg.AVA.TEST_FORCE_FLIP
#     211
# --> 212         self._load_data(cfg)
#     213
#     214     def _load_data(self, cfg):
#
# ~\deep_learning\sesame\sesame\datasets\ava_dataset.py in _load_data(self, cfg)
#     238         )
#     239
# --> 240         self.print_summary()
#     241
#     242     def print_summary(self):
#
# ~\deep_learning\sesame\sesame\datasets\ava_dataset.py in print_summary(self)
#     243         log.info("=== AVA dataset summary ===")
#     244         log.info("Split: {}".format(self._split))
# --> 245         log.info("Number of video: {}".format(len(self._image_paths)))
#     246         # total_frames = sum(
#     247         #     len(video_img_paths) for video_img_paths in self._image_paths
#
# D:\anaconda3\lib\site-packages\torch\utils\data\dataset.py in __getattr__(self, attribute_name)
#      81             return function
#      82         else:
# ---> 83             raise AttributeError
#      84
#      85     @classmethod
#
# AttributeError:
